# %%
# %sql
USE `sudong`.`agent_bricks`;

CREATE or replace TABLE equipment_parts (
    Equipment_ID STRING COMMENT '설비번호',
    Equipment_Name STRING COMMENT '설비명',
    Material_ID STRING COMMENT '부품번호',
    Material_Name STRING COMMENT '부품명',
    Plant_Code STRING COMMENT '플랜트코드',
    Vendor_ID STRING COMMENT '공급업체코드',
    Vendor_Name STRING COMMENT '공급업체명',
    Unit_Price DECIMAL(18,2) COMMENT '단가',
    Currency STRING COMMENT '통화',
    Unit_of_Measure STRING COMMENT '단위',
    Delivery_Lead_Time_Days INT COMMENT '납기일_일',
    Last_Maintenance_Date DATE COMMENT '최종정비일',
    PM_Cycle_Days INT COMMENT '정비주기_일',
    Current_Stock INT COMMENT '현재재고수량'
);

INSERT INTO equipment_parts VALUES
('100001','주스병 에어 세척 장비','FLT-HEPA-02M','메인 에어 필터 카트리지 (0.2µm HEPA)','1000','101000','Global Filters Corp.',150.00,'USD','EA',14,'2025-09-01',180, 12),
('100001','주스병 에어 세척 장비','FLT-PRE-5M','프리 필터 카트리지 (5µm)','1000','101000','Global Filters Corp.',25.00,'USD','EA',14,'2025-10-01',90, 7),
('100001','주스병 에어 세척 장비','GKT-OR-V10','노즐 O-링 (Viton)','1000','103020','K-Parts Solution',1500.00,'KRW','EA',3,'2025-09-01',365, 3),
('100001','주스병 에어 세척 장비','MEC-GRP-PAD01','병 반전 장치 그리퍼 패드','1000','103020','K-Parts Solution',35000.00,'KRW','EA',5,'2025-09-01',180, 8),
('100002','주스병 린싱 장비','NZL-RINSE-S316','린싱 노즐 (스테인리스 스틸)','1000','102005','Precision Nozzles GmbH',45.50,'EUR','EA',21,'2025-10-15',90, 5),
('100002','주스병 린싱 장비','PMP-SEAL-MEC01','고압 펌프 메카니컬 씰','1000','105000','American Bearings Inc.',120.00,'USD','EA',30,'2025-04-01',365, 2),
('100002','주스병 린싱 장비','FLT-PRE-CART02','전처리 필터 카트리지','1000','101000','Global Filters Corp.',55.00,'USD','EA',14,'2025-10-01',90, 10),
('100002','주스병 린싱 장비','SEN-PHOTO-D100','광전 센서','1000','104010','Tokyo Sensors Co.',12500.00,'JPY','EA',25,'2025-08-01',365, 4),
('100003','병 살균 장비','NZL-STER-PAA05','살균제 분사 노즐 (PAA용)','1000','102005','Precision Nozzles GmbH',68.00,'EUR','EA',21,'2025-10-01',180, 6),
('100003','병 살균 장비','GKT-SEAL-E25','연결부 개스킷 (EPDM)','1000','103020','K-Parts Solution',4500.00,'KRW','EA',3,'2025-10-01',90, 9),
('100003','병 살균 장비','SEN-COND-C01','농도 센서','1000','104010','Tokyo Sensors Co.',85000.00,'JPY','EA',25,'2025-09-15',90, 1),
('100003','병 살균 장비','VLV-CTRL-P01','공압 제어 밸브','1000','103020','K-Parts Solution',280000.00,'KRW','EA',7,'2025-07-01',365, 13),
('100004','주스병 건조 장비','MEC-AIRKNIFE-A1','에어 나이프 (알루미늄)','1000','102005','Precision Nozzles GmbH',210.00,'EUR','EA',21,'2025-09-01',180, 11),
('100004','주스병 건조 장비','MOT-BLW-BRG01','블로워 모터 베어링','1000','105000','American Bearings Inc.',75.00,'USD','EA',30,'2025-05-01',365, 15),
('100004','주스병 건조 장비','BELT-CONV-AC1','컨베이어 벨트 (Acetal)','1000','103020','K-Parts Solution',120000.00,'KRW','M',5,'2025-09-01',365, 18),
('100005','착즙 장비','MEC-BLADE-J2','착즙기 칼날 세트','1000','103020','K-Parts Solution',180000.00,'KRW','EA',5,'2025-10-15',60, 14),
('100005','착즙 장비','FLT-STRAIN-M200','착즙 필터 (200 마이크론)','1000','101000','Global Filters Corp.',95.00,'USD','EA',14,'2025-10-01',90, 16),
('100005','착즙 장비','GKT-SEAL-J05','프레스 고무 씰','1000','105000','American Bearings Inc.',35.00,'USD','EA',30,'2025-08-01',180, 20),
('100005','착즙 장비','OIL-HYD-VG46','유압유 (VG46)','1000','103020','K-Parts Solution',85000.00,'KRW','L',3,'2025-01-01',365, 17);
