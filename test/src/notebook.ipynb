# %% [markdown]
# # Default notebook
#
# This default notebook is executed using Databricks Workflows as defined in resources/test.job.yml.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from test import main

main.find_all_taxis().show(10)
